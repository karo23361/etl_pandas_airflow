# %%
import pandas as pd 
import numpy as np

# %%
df = pd.read_csv("dirty_cafe_sales.csv")

# %%
df.count()
# Out:
# Transaction ID      10000
# Item                 9667
# Quantity             9862
# Price Per Unit       9821
# Total Spent          9827
# Payment Method       7421
# Location             6735
# Transaction Date     9841
# dtype: int64

# %%
#################################### ITEM ####################################

df[df["Item"].isin(["UNKNOWN", "ERROR"]) | df["Item"].isna()]

#df['Item'].isin(['UNKNOWN', 'ERROR']).mean() 
#0.0636


#df["Item"].replace("ERROR", "UNKNOWN")
#df["Item"].fillna("UNKNOWN")
#df["Item"].unique()
#array(['Coffee', 'Cake', 'Cookie', 'Salad', 'Smoothie', 'UNKNOWN',
       #'Sandwich', nan, 'ERROR', 'Juice', 'Tea'], dtype=object)
#Replacing Error/nan into UKNOWN
# Out:
#      Transaction ID     Item Quantity Price Per Unit Total Spent  \
# 6       TXN_4433211  UNKNOWN        3            3.0         9.0
# 8       TXN_4717867      NaN        5            3.0        15.0
# 14      TXN_8915701    ERROR        2            1.5         3.0
# 30      TXN_1736287      NaN        5            2.0        10.0
# 31      TXN_8927252  UNKNOWN        2            1.0       ERROR
# ...             ...      ...      ...            ...         ...
# 9951    TXN_4122925    ERROR        4            1.0         4.0
# 9958    TXN_4125474    ERROR        2            5.0        10.0
# 9981    TXN_4583012    ERROR        5            4.0        20.0
# 9994    TXN_7851634  UNKNOWN        4            4.0        16.0
# 9996    TXN_9659401      NaN        3            NaN         3.0
#
#       Payment Method  Location Transaction Date
# 6              ERROR  Takeaway       2023-10-06
# 8                NaN  Takeaway       2023-07-28
# ...

# %%
df_menu = {'Item': ['Coffee', 'Tea', ' Sandwich', 'Salad', 'Cake', 'Cookie', 'Smoothie', 'Juice'],
           'Price': [2.0, 1.5, 4.0, 5.0, 3.0, 1.0, 4.0 , 3.0]}

# %%
df_menu = pd.DataFrame(df_menu)
df["Price Per Unit"] = pd.to_numeric(df["Price Per Unit"], errors='coerce')
df_menu["Price"] = pd.to_numeric(df_menu["Price"], errors="coerce")

# %%
price_to_item = df_menu.set_index("Price")["Item"].to_dict()

# %%
invalid_items = ['UNKNOWN', 'ERROR', None, '', pd.NA, np.nan]
df["Item"] = df["Item"].replace(invalid_values, pd.NA)

# %%
mask = df["Item"].isna() & df["Price Per Unit"].isin(price_to_item.keys())
df.loc[mask, "Item"] = df.loc[mask, "Price Per Unit"].map(price_to_item)

# %%
df.head(15)
# Out:
#    Transaction ID      Item Quantity  Price Per Unit Total Spent  \
# 0     TXN_1961373    Coffee        2             2.0         4.0
# 1     TXN_4977031      Cake        4             3.0        12.0
# 2     TXN_4271903    Cookie        4             1.0       ERROR
# 3     TXN_7034554     Salad        2             5.0        10.0
# 4     TXN_3160411    Coffee        2             2.0         4.0
# 5     TXN_2602893  Smoothie        5             4.0        20.0
# 6     TXN_4433211     Juice        3             3.0         9.0
# 7     TXN_6699534  Sandwich        4             4.0        16.0
# 8     TXN_4717867     Juice        5             3.0        15.0
# 9     TXN_2064365  Sandwich        5             4.0        20.0
# 10    TXN_2548360     Salad        5             5.0        25.0
# 11    TXN_3051279  Sandwich        2             4.0         8.0
# 12    TXN_7619095  Sandwich        2             4.0         8.0
# ...

# %%
########################### QUANTITY ###########################

df[df["Quantity"].isin(["ERROR", "UNKNOWN", None, pd.NA, np.nan])]
# Out:
#      Transaction ID      Item Quantity  Price Per Unit Total Spent  \
# 20      TXN_3522028  Smoothie    ERROR             4.0        20.0
# 55      TXN_5522862    Cookie    ERROR             1.0         2.0
# 57      TXN_2080895      Cake  UNKNOWN             3.0         3.0
# 66      TXN_8501819     Juice      NaN             3.0         6.0
# 117     TXN_2148617     Juice    ERROR             3.0         9.0
# ...             ...       ...      ...             ...         ...
# 9932    TXN_8502079       Tea  UNKNOWN             1.5         3.0
# 9935    TXN_9778251       Tea    ERROR             1.5         6.0
# 9944    TXN_7495283      Cake  UNKNOWN             3.0        15.0
# 9957    TXN_6487003    Coffee    ERROR             2.0         8.0
# 9984    TXN_3142496  Smoothie  UNKNOWN             4.0         4.0
#
#       Payment Method  Location Transaction Date
# 20              Cash  In-store       2023-04-04
# 55       Credit Card  Takeaway       2023-03-19
# ...

# %%
df["Total Spent"] = pd.to_numeric(df["Total Spent"], errors='coerce')
df["Price Per Unit"] = pd.to_numeric(df["Price Per Unit"], errors='coerce')

# %%
invalid_values = ["ERROR", "UNKNOWN", None, "", pd.NA, np.nan]
mask = df["Quantity"].isin(invalid_items) | df["Quantity"].isna()

# %%
df.loc[mask, "Quantity"] = df.loc[mask, "Total Spent"] / df.loc[mask, "Price Per Unit"]

# %%
df[df["Quantity"].isna() | df["Quantity"].isin(invalid_values)]
# Out:
#      Transaction ID      Item Quantity  Price Per Unit  Total Spent  \
# 236     TXN_8562645     Salad      NaN             5.0          NaN
# 278     TXN_3229409     Juice      NaN             3.0          NaN
# 629     TXN_9289174      Cake      NaN             NaN         12.0
# 641     TXN_2962976     Juice      NaN             3.0          NaN
# 738     TXN_8696094  Sandwich      NaN             4.0          NaN
# 912     TXN_1575608  Sandwich      NaN             NaN         20.0
# 1008    TXN_7225428       Tea      NaN             NaN          3.0
# 1436    TXN_7590801       Tea      NaN             NaN          6.0
# 1482    TXN_3593060  Smoothie      NaN             NaN         16.0
# 2330    TXN_3849488     Salad      NaN             NaN          5.0
# 2796    TXN_9188692      Cake      NaN             3.0          NaN
# 3203    TXN_4565754  Smoothie      NaN             4.0          NaN
# 3224    TXN_6297232    Coffee      NaN             2.0          NaN
# ...

# %%
df = df.dropna(subset=["Quantity"])

# %%
df = df.dropna(subset=["Item"])

# %%
df[df["Item"].isna() | df["Item"].isin(invalid_values)]
# Out:
# Empty DataFrame
# Columns: [Transaction ID, Item, Quantity, Price Per Unit, Total Spent, Payment Method, Location, Transaction Date]
# Index: []

# %%
df_menu = pd.DataFrame({'Item': ['Coffee', 'Tea', 'Sandwich', 'Salad', 'Cake', 'Cookie', 'Smoothie', 'Juice'],
           'Price': [2.0, 1.5, 4.0, 5.0, 3.0, 1.0, 4.0 , 3.0]})

item_to_price = df_menu.set_index("Item")["Price"].to_dict()
mask = df["Price Per Unit"].isna() | df["Price Per Unit"].isin(invalid_values)
df.loc[mask, "Price Per Unit"] = df.loc[mask, "Item"].map(item_to_price)

# %%
mask = df["Total Spent"].isna() | df["Total Spent"].isin(invalid_values)

# %%
df["Total Spent"] = pd.to_numeric(df["Total Spent"], errors='coerce')
df["Quantity"] = pd.to_numeric(df["Quantity"], errors='coerce')
df["Price Per Unit"] = pd.to_numeric(df["Price Per Unit"], errors='coerce')

# %%
df.loc[mask, "Total Spent"] = df.loc[mask, "Quantity"] * df.loc[mask, "Price Per Unit"]

# %%
df[df["Total Spent"].isin(invalid_values) | df["Total Spent"].isna()]
# Out:
# Empty DataFrame
# Columns: [Transaction ID, Item, Quantity, Price Per Unit, Total Spent, Payment Method, Location, Transaction Date]
# Index: []

# %%
df[df["Payment Method"].isin(invalid_values) | df["Payment Method"].isna()]
# Out:
#      Transaction ID      Item  Quantity  Price Per Unit  Total Spent  \
# 3       TXN_7034554     Salad       2.0             5.0         10.0
# 6       TXN_4433211     Juice       3.0             3.0          9.0
# 8       TXN_4717867     Juice       5.0             3.0         15.0
# 9       TXN_2064365  Sandwich       5.0             4.0         20.0
# 13      TXN_9437049    Cookie       5.0             1.0          5.0
# ...             ...       ...       ...             ...          ...
# 9985    TXN_3297457      Cake       2.0             3.0          6.0
# 9988    TXN_9594133      Cake       5.0             3.0         15.0
# 9992    TXN_2739140  Smoothie       4.0             4.0         16.0
# 9994    TXN_7851634  Smoothie       4.0             4.0         16.0
# 9995    TXN_7672686    Coffee       2.0             2.0          4.0
#
#      Payment Method  Location Transaction Date
# 3           UNKNOWN   UNKNOWN       2023-04-27
# ...

# %%
#df["Payment Method"] = df["Payment Method"].replace(invalid_values, pd.NA)
#df["Payment Method"] = df["Payment Method"].replace(pd.NA, None)
df["Payment Method"] = df["Payment Method"].replace(invalid_values, np.nan)

# %%
df.head(20)
# Out:
#    Transaction ID      Item  Quantity  Price Per Unit  Total Spent  \
# 0     TXN_1961373    Coffee       2.0             2.0          4.0
# 1     TXN_4977031      Cake       4.0             3.0         12.0
# 2     TXN_4271903    Cookie       4.0             1.0          4.0
# 3     TXN_7034554     Salad       2.0             5.0         10.0
# 4     TXN_3160411    Coffee       2.0             2.0          4.0
# 5     TXN_2602893  Smoothie       5.0             4.0         20.0
# 6     TXN_4433211     Juice       3.0             3.0          9.0
# 7     TXN_6699534  Sandwich       4.0             4.0         16.0
# 8     TXN_4717867     Juice       5.0             3.0         15.0
# 9     TXN_2064365  Sandwich       5.0             4.0         20.0
# 10    TXN_2548360     Salad       5.0             5.0         25.0
# 11    TXN_3051279  Sandwich       2.0             4.0          8.0
# 12    TXN_7619095  Sandwich       2.0             4.0          8.0
# ...

# %%
df["Location"] = df["Location"].replace(invalid_values, np.nan)

# %%
df[df["Transaction Date"].isna() | df["Transaction Date"].isin(invalid_values)]
# Out:
#      Transaction ID      Item  Quantity  Price Per Unit  Total Spent  \
# 11      TXN_3051279  Sandwich       2.0             4.0          8.0
# 29      TXN_7640952      Cake       4.0             3.0         12.0
# 33      TXN_7710508    Cookie       5.0             1.0          5.0
# 77      TXN_2091733     Salad       1.0             5.0          5.0
# 103     TXN_7028009      Cake       4.0             3.0         12.0
# ...             ...       ...       ...             ...          ...
# 9933    TXN_9460419      Cake       1.0             3.0          3.0
# 9937    TXN_8253472      Cake       1.0             3.0          3.0
# 9949    TXN_3130865     Juice       3.0             3.0          9.0
# 9983    TXN_9226047  Smoothie       3.0             4.0         12.0
# 9988    TXN_9594133      Cake       5.0             3.0         15.0
#
#       Payment Method  Location Transaction Date
# 11       Credit Card  Takeaway            ERROR
# ...

# %%
df["Transaction Date"] = df["Transaction Date"].replace(invalid_values, np.nan)

# %%
df[df["Transaction Date"].isna() | df["Transaction Date"].isin(invalid_values)]
# Out:
# Empty DataFrame
# Columns: [Transaction ID, Item, Quantity, Price Per Unit, Total Spent, Payment Method, Location, Transaction Date]
# Index: []

# %%
df["Transaction Date"] = pd.to_datetime(df["Transaction Date"], errors="coerce")

# %%
df["Transaction Date"] = df["Transaction Date"].fillna(method="ffill")
# Out:
# C:\Users\karo2\AppData\Local\Temp\ipykernel_19888\1801787190.py:1: FutureWarning: Series.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df["Transaction Date"] = df["Transaction Date"].fillna(method="ffill")

# %%
df.head(15)
# Out:
#    Transaction ID      Item  Quantity  Price Per Unit  Total Spent  \
# 0     TXN_1961373    Coffee       2.0             2.0          4.0
# 1     TXN_4977031      Cake       4.0             3.0         12.0
# 2     TXN_4271903    Cookie       4.0             1.0          4.0
# 3     TXN_7034554     Salad       2.0             5.0         10.0
# 4     TXN_3160411    Coffee       2.0             2.0          4.0
# 5     TXN_2602893  Smoothie       5.0             4.0         20.0
# 6     TXN_4433211     Juice       3.0             3.0          9.0
# 7     TXN_6699534  Sandwich       4.0             4.0         16.0
# 8     TXN_4717867     Juice       5.0             3.0         15.0
# 9     TXN_2064365  Sandwich       5.0             4.0         20.0
# 10    TXN_2548360     Salad       5.0             5.0         25.0
# 11    TXN_3051279  Sandwich       2.0             4.0          8.0
# 12    TXN_7619095  Sandwich       2.0             4.0          8.0
# ...

# %%
df["Year"] = df["Transaction Date"].dt.year
df["Month"] = df["Transaction Date"].dt.month
df["Month_Name"] = df["Transaction Date"].dt.month_name()
df["Quarter"] = df["Transaction Date"].dt.quarter
df["Week"] = df["Transaction Date"].dt.isocalendar().week
df["Day"] = df["Transaction Date"].dt.day
df["Day_Name"] = df["Transaction Date"].dt.day_name()
df["Is_Weekend"] = df["Day_Name"].isin(["Saturday", "Sunday"])

# %%
df.head(10)
# Out:
#   Transaction ID      Item  Quantity  Price Per Unit  Total Spent  \
# 0    TXN_1961373    Coffee       2.0             2.0          4.0
# 1    TXN_4977031      Cake       4.0             3.0         12.0
# 2    TXN_4271903    Cookie       4.0             1.0          4.0
# 3    TXN_7034554     Salad       2.0             5.0         10.0
# 4    TXN_3160411    Coffee       2.0             2.0          4.0
# 5    TXN_2602893  Smoothie       5.0             4.0         20.0
# 6    TXN_4433211     Juice       3.0             3.0          9.0
# 7    TXN_6699534  Sandwich       4.0             4.0         16.0
# 8    TXN_4717867     Juice       5.0             3.0         15.0
# 9    TXN_2064365  Sandwich       5.0             4.0         20.0
#
#    Payment Method  Location Transaction Date  Year  Month Month_Name  Quarter  \
# 0     Credit Card  Takeaway       2023-09-08  2023      9  September        3
# 1            Cash  In-store       2023-05-16  2023      5        May        2
# ...

# %%
df = df.drop(columns=["Transaction Date"])

# %%
df.head(2)
# Out:
#   Transaction ID    Item  Quantity  Price Per Unit  Total Spent  \
# 0    TXN_1961373  Coffee       2.0             2.0          4.0
# 1    TXN_4977031    Cake       4.0             3.0         12.0
#
#   Payment Method  Location  Year  Month Month_Name  Quarter  Week  Day  \
# 0    Credit Card  Takeaway  2023      9  September        3    36    8
# 1           Cash  In-store  2023      5        May        2    20   16
#
#   Day_Name  Is_Weekend
# 0   Friday       False
# 1  Tuesday       False
